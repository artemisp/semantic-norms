# %% [markdown]
# # Feature Norms

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
matplotlib.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt

fig, ax = plt.subplots(constrained_layout=True, figsize=(8, 6))
csfont = {'fontname':'Times New Roman'}
m_size = 5
lw = 0.5

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['legend.title_fontsize'] = 18

cp = [round(0.1 * i, 1) for i in range(11)]
scores = [24.6, 37.9, 39.1, 39.7, 39.3, 38.7, 39.1, 37.5, 36.0, 34.8, 26.1]
scores_1 = [24.6, 27.1, 27.3, 28.1, 28.7, 30.3, 29.5, 29.1, 29.1, 29.5, 27.3]
scores_2 = [24.6, 25.0, 25.9, 25.5, 26.1, 27.9, 29.9, 28.9, 28.9, 26.3, 22.0]
scores_3 = [24.6, 31.0, 34.6, 34.2, 34.2, 34.4, 35.2, 32.8, 32.6, 31.4, 27.9]

plt.axhline(y=40.1, color='gray', label = 'CEM',linestyle='-.')
plt.axhline(y=24.6, color='gray', label = 'RoBERTa',linestyle='-')

plt.plot(cp, scores, 'D-', label = 'RoBERTa + CLIP', linewidth = lw, markersize=5, markerfacecolor='cyan', alpha=1)
plt.plot(cp, scores_3, '^-', label = 'RoBERTa + ViLT', linewidth = lw, color='red', markersize=5, markerfacecolor='red', alpha=1)
plt.plot(cp, scores_2, 'x-', label = 'RoBERTa + GPT-2', linewidth = lw, color='green', markersize=5, alpha=1)
plt.plot(cp, scores_1, 'o-', label = 'RoBERTa + BERT', linewidth = lw, color='green', markersize=5, markerfacecolor='springgreen', alpha=1)

plt.annotate("RoBERTa", (0, 23.5), fontsize = 16)
plt.annotate("CLIP", (0.96, 25), fontsize = 16)
plt.annotate("BERT", (0.95, 26.5), fontsize = 16)
plt.annotate("GPT-2", (0.95, 21), fontsize = 16)
plt.annotate("ViLT", (0.96, 28.5), fontsize = 16)
plt.ylim(18, 42)
plt.legend(fontsize = 15, loc='lower center', ncol = 2)
# plt.title("Transfer-learning on Howto100m Video Frames \n with Random Sampling", fontsize = 12)
plt.xlabel(r'weigh-$w$', fontsize = 20)
plt.yticks(fontsize = 16)
plt.xticks(fontsize = 16)
plt.ylabel(r"Accuracy@1", fontsize = 20)

plt.savefig('combine_models.pdf', format='pdf', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Concept Properties

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
matplotlib.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt

fig, ax = plt.subplots(constrained_layout=True, figsize=(8, 6))
csfont = {'fontname':'Times New Roman'}
m_size = 5
lw = 0.5

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['legend.title_fontsize'] = 18

cp = [round(0.1 * i, 1) for i in range(11)]
scores = [32.4, 46.9, 47.3, 47.8, 48.1, 47.8, 48.9, 47.6, 47.8, 47.3, 29.5]
scores_1 = [24.6, 27.1, 27.3, 28.1, 28.7, 30.3, 29.5, 29.1, 29.1, 29.5, 27.3]
scores_2 = [24.6, 25.0, 25.9, 25.5, 26.1, 27.9, 29.9, 28.9, 28.9, 26.3, 22.0]
scores_3 = [24.0, 28.5, 29.1, 30.5, 32.0, 30.8, 32.6, 33.0, 32.2, 31.0, 27.9]

plt.axhline(y=42.8, color='black', label = 'CEM',linestyle='-.')
plt.plot(cp, scores, 'D-', label = 'Roberta + CLIP', linewidth = lw, markersize=5, markerfacecolor='cyan', alpha=1)
plt.plot(cp, scores_1, 'D-', label = 'Roberta + BERT', linewidth = lw, markersize=5, markerfacecolor='antiquewhite', alpha=1)
plt.plot(cp, scores_2, 'D-', label = 'Roberta + GPT-2', linewidth = lw, markersize=5, markerfacecolor='springgreen', alpha=1)


plt.annotate("Roberta", (0, 23.5), fontsize = 16)
plt.annotate("CLIP", (0.95, 30), fontsize = 16)
plt.annotate("BERT", (0.95, 25.9), fontsize = 16)
plt.annotate("GPT-2", (0.94, 20.6), fontsize = 16)
plt.ylim(20, 45)
plt.legend(fontsize = 12, loc='best')
# plt.title("Transfer-learning on Howto100m Video Frames \n with Random Sampling", fontsize = 12)
plt.xlabel(r'weight', fontsize = 20)
plt.yticks(fontsize = 16)
plt.xticks(fontsize = 16)
plt.ylabel(r"Top 1 Accuracy", fontsize = 20)

plt.savefig('combine_models.pdf', format='pdf', dpi=600, bbox_inches='tight')
plt.show()
